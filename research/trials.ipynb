# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Projects\\End-to-End-ML-Classification-Project-with-MLflow-\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Projects\\End-to-End-ML-Classification-Project-with-MLflow-'

# %%
import pandas as pd

# %%
df = pd.read_excel("artifacts/data_ingestion/Glaucoma_Data.xlsx")

# %%
df.head()
# Out:
#    casetype   age  gender  education  employment  tribal_you heightcm1  \
# 0         2  68.0       1        3.0         1.0         5.0       166
# 1         2  78.0       1        5.0         1.0         4.0       163
# 2         2  67.0       1        3.0         1.0         4.0     159.6
# 3         1  71.0       1        5.0         2.0         4.0     169.5
# 4         1  43.0       2        5.0         1.0         4.0       158
#
#    weightkg1  sys_press_meas1  dia_press_meas1  ...  sup_rnft_re  sup_rnft_le  \
# 0       66.0            180.0             90.0  ...          106        100.0
# 1       78.0            140.0             90.0  ...          123        111.0
# 2       61.0            100.0             60.0  ...           92         80.0
# 3       52.0            130.0             70.0  ...          NaN          NaN
# 4       71.0            100.0             60.0  ...          NaN         63.0
#
# ...

# %%
df['casetype'].value_counts()
# Out:
# casetype
# 1    4954
# 2    4015
# Name: count, dtype: int64

# %%
all_schema = self.config.all_schema.keys()
